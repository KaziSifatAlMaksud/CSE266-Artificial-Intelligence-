# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd/content/drive/MyDrive/Python/ML/Linear\ regression
# Out:
# /content/drive/MyDrive/Python/ML/Linear regression

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
dataset = pd.read_csv('insurance.csv')
dataset
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
label = LabelEncoder()
label.fit(dataset.sex.drop_duplicates())
dataset.sex = label.transform(dataset.sex)

label.fit(dataset.smoker.drop_duplicates())
dataset.smoker = label.transform(dataset.smoker)


label.fit(dataset.region.drop_duplicates())
dataset.region = label.transform(dataset.region)
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ca96c721ff75> in <module>
# ----> 1 label = LabelEncoder()
#       2 label.fit(dataset.sex.drop_duplicates())
#       3 dataset.sex = label.transform(dataset.sex)
#       4
#       5 label.fit(dataset.smoker.drop_duplicates())
#
# NameError: name 'LabelEncoder' is not defined

# %%
x = dataset.drop(['expenses'], axis ='columns')
y = dataset[['expenses']]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(x_test)

# %%
model.score(x_test,prediction)
# Out:
# 1.0
